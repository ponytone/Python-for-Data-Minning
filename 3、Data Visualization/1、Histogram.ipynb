# %% [markdown]
# # Histogram

# %%
import numpy as np
from numpy.random import randn
import pandas as pd

from scipy import stats

import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
# Create a random normal-dist dataset
dataset1 = randn(100)

# Plot a histogram of the dataset, note bins=10 by default
plt.hist(dataset1)
# Out:
# (array([ 3.,  4.,  9., 11., 23., 18., 18., 10.,  3.,  1.]),
#  array([-2.29287921, -1.82791233, -1.36294545, -0.89797857, -0.4330117 ,
#          0.03195518,  0.49692206,  0.96188894,  1.42685581,  1.89182269,
#          2.35678957]),
#  <a list of 10 Patch objects>)

# %%
# Let's make another dataset
dataset2 = randn(80)

# plot
plt.hist(dataset2,color = 'indianred')
# Out:
# (array([ 5., 14., 11., 15., 15., 12.,  3.,  3.,  1.,  1.]),
#  array([-1.63213467, -1.18425356, -0.73637245, -0.28849134,  0.15938977,
#          0.60727088,  1.05515199,  1.50303309,  1.9509142 ,  2.39879531,
#          2.84667642]),
#  <a list of 10 Patch objects>)

# %%
# We can use normed to plot on same plot
# Set normed=True for the plots to be normalized in order to comapre data sets with different number of observations
# Set alpha=0.5 for transperancy
plt.hist(dataset1,density=False,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=False,alpha=0.5,bins=20)
# Out:
# (array([1., 4., 6., 8., 4., 7., 7., 8., 7., 8., 7., 5., 2., 1., 1., 2., 1.,
#         0., 0., 1.]),
#  array([-1.63213467, -1.40819411, -1.18425356, -0.960313  , -0.73637245,
#         -0.51243189, -0.28849134, -0.06455079,  0.15938977,  0.38333032,
#          0.60727088,  0.83121143,  1.05515199,  1.27909254,  1.50303309,
#          1.72697365,  1.9509142 ,  2.17485476,  2.39879531,  2.62273587,
#          2.84667642]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(dataset1,density=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)
# Out:
# (array([0.05581838, 0.22327354, 0.33491031, 0.44654708, 0.22327354,
#         0.39072869, 0.39072869, 0.44654708, 0.39072869, 0.44654708,
#         0.39072869, 0.27909192, 0.11163677, 0.05581838, 0.05581838,
#         0.11163677, 0.05581838, 0.        , 0.        , 0.05581838]),
#  array([-1.63213467, -1.40819411, -1.18425356, -0.960313  , -0.73637245,
#         -0.51243189, -0.28849134, -0.06455079,  0.15938977,  0.38333032,
#          0.60727088,  0.83121143,  1.05515199,  1.27909254,  1.50303309,
#          1.72697365,  1.9509142 ,  2.17485476,  2.39879531,  2.62273587,
#          2.84667642]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ## seaborn

# %%
# Make two more random normal dist data sets
data1 = randn(1000)
data2 = randn(1000)

#Can represent joint distributions using joint plots
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind = 'kde')
